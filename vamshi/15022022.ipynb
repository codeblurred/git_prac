# %%
# ##################### seconds  ##############################

print(f"65 days are {65*24*60*60} Seconds ")
#  f stands for format (basically we are formatting our texts or strings in a correct way )

a = int(input("enter the value for the number of days : "))
minutes = 24*60
seconds = 24*60*60
print(f"{a} days are {a*minutes} minutes")
print(f"{a} days are {a*seconds} Seconds ")

print(f"{a} days are {a*minutes} minutes & {a*seconds} Seconds ")

###### code refinement
# Out:
# 65 days are 5616000 Seconds
# enter the value for the number of days : 20
# 20 days are 28800 minutes
# 20 days are 1728000 Seconds
# 20 days are 28800 minutes & 1728000 Seconds

# %%
a = int(input("enter the value for the number of days : "))
minutes = 24*60
seconds = 24*60*60

def auto_day_calc():
    if a > 1:
        print(f"{a} days are {a * minutes} minutes & {a * seconds} Seconds ")
    else:
        print(f"{a} day is {a * minutes} minutes & {a * seconds} Seconds ")



auto_day_calc()
# Out:
# enter the value for the number of days : 10
# 10 days are 14400 minutes & 864000 Seconds

# %%
################ <<<<<<<<<<<<<<  def function            >>>>>>>>>>>>>>>>>##################################


calc_hours = 24
h = "hours"
d = int(input("enter the value for the number of days : "))

#  any variable declared outside the def is global for ex: calc_hours,h,d

def days_hours(d):
    print(f"{d} days are {d*calc_hours} {h}")


days_hours(d)
# Out:
# enter the value for the number of days : 20
# 20 days are 480 hours

# %%
######################################################################
######## calc_hours and h are global variables as they declared out side the def function

calc_hours = 24
h = "hours"

def days_hours(d,cust_msg):      # d,cust_msg are local variables as they were create inside the function and can only run be inside the function

    print(f"{d} days are {d*calc_hours} {h} \n {cust_msg}")


days_hours(2, "awesome!!")

#####################################################################
# Out:
# 2 days are 48 hours
#  awesome!!

# %%
calc_hours = 24
h = "hours"
d = int(input("enter the value for the number of days : "))
cust_msg = input(" enter your message :  ")

def days_hours(days, custom_msg):

    print(f"{d} days are {d * calc_hours} {h} \n {cust_msg}")  # uses global variables
    print(f"{days} days are {days * calc_hours} {h} \n {custom_msg}") # uses local variables

days_hours(4, " woah !! ")


# days_hours(4, " it works !!! ") # looks for local variables from def
#
# days_hours(d, cust_msg) # picks from the globally declared variable
# Out:
# enter the value for the number of days : 20
#  enter your message :  woah 20 days !!!
# 20 days are 480 hours
#  woah 20 days !!!
# 4 days are 96 hours
#   woah !!

# %%
calc_hours = 24
h = "hours"
d = int(input("enter the value for the number of days : "))
cust_msg = input(" enter your message :  ")

def days_hours(days, custom_msg):

    print(f"{d} days are {d * calc_hours} {h} \n {cust_msg}")  # uses global variables
    print(f"{days} days are {days * calc_hours} {h} \n {custom_msg}") # uses local variables

days_hours(4, " woah !! ")

def scope_check():
    print(calc_hours,d,h)
#     print(custom_msg)
    # Unresolved reference 'custom_msg' which means 'custom_msg' that was declared as local variable above cannot be used here locally
    # if 'custom_msg' were a global variable , we could have referred here in this def function

scope_check()

def scope_check1(custom_msg): # since we have declared the custom_msg variable locally here , python wont throw any errors
    my_var = " variable inside  function "
    print(f"global variables are {calc_hours,d,h}")
    print(f"{custom_msg} is locally declared  variable \n \n")
    print("my_var is ",my_var)
    

# scope_check1("custom message")
# Out:
# enter the value for the number of days : 10
#  enter your message :  no not 10 please
# 10 days are 240 hours
#  no not 10 please
# 4 days are 96 hours
#   woah !!
# 24 10 hours

# %%
calc_hours = 24
h = "hours"
cust_msg = input(" enter your message :  ")
print(cust_msg)


def days_hours(days, custom_msg):
    return f"{days} days are {days * calc_hours} {h} \n {custom_msg}"  # uses local variables


#  what would happen if we assign the result of calling the days_hours(4, " woah !! ") to a variable ?
#  well we get a warning and it says function does not return anything
#  and thus we use the return keyword to return the value

my_var = days_hours(4, " woah !! ")

print(my_var)

# return is a built-in python keyword used to end the execution of a function call
# and returns the result (value of the expression followed by the return key word )
#  a function can return  data as a result

######### STEPS OF EXECUTION :
# 1 function is executed
# 2 return value is assigned to variable
# 3 Variable value is print to standard output
# Out:
#  enter your message :  hey there
# hey there
# 4 days are 96 hours
#   woah !!

# %%
calc_hours = 24
h = "hours"
d = int(input("enter the value for the number of days : "))
cust_msg = input(" enter your message :  ")

def days_hours(days, custom_msg):

    print(f"{d} days are {d * calc_hours} {h} \n {cust_msg}")  # uses global variables
    print(f"{days} days are {days * calc_hours} {h} \n {custom_msg}") # uses local variables

days_hours(4, " woah !! ")

days_hours(d,cust_msg)
# Out:
# enter the value for the number of days : 20
#  enter your message :  20 days !!
# 20 days are 480 hours
#  20 days !!
# 4 days are 96 hours
#   woah !!
# 20 days are 480 hours
#  20 days !!
# 20 days are 480 hours
#  20 days !!
