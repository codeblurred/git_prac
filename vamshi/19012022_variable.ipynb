# %%
'''this is a comment'''
# this is a comment
# Out:
# 'this is a comment'

# %%
# legal way of declaring variables 
myname = 'sumanth'
my_name = 'sumanth'
_my_name = "sumanth"
myName = "sumanth"
MyName = "sumanth"
myname72 = 'sumanth'


print(myname, my_name, _my_name,myName, MyName, myname72)
# Out:
# sumanth sumanth sumanth sumanth sumanth sumanth

# %%
# not acceptable ways of declaring a variable 
# 8myname = 'sumanth'
# my-name = 'sumanth'
# my name = "sumanth"

# Camel Case
# myDogName = "randomname"

# Pascal Case 
# MyDogName = "randomname"

# Snake Case 
# my_dog_name = "randomname"

# %%
name = "sumanth"
print(" hi there!! i am "+name )
# print(" hi there!! i am " name ) 
print(" hi there!! i am ",name )
# Out:
#  hi there!! i am sumanth
#  hi there!! i am  sumanth

# %%
# different values to multiple variables

a,b,c = "apple","banana","cherry"

# same value to multiple variables
x = y= z = "cars"

# %%
name = "sumanth"
age = "10" 
residence = " abc palace"

print("my name is "+name, "my age is "+age, "i dwell at "+ residence)
# Out:
# my name is sumanth my age is 10 i dwell at  abc palace

# %%
day = "wednesday"
car = "random cars"

def myday():
    print("my lucky day is " + day, " i love riding in " + car )

# %%
# myday
# <function __main__.myday()>
# Out:
# <function __main__.myday()>

# %%
myday()
# Out:
# my lucky day is wednesday  i love riding in random cars

# %%
print
# Out:
# <function print>

# %%
day = "wednesday"
car = "random cars"

def myday():
    day = "Monday"
    car = "blue cars"
    
    print("my lucky day is " + day, "and i love riding in " + car )

# %%
myday()
# Out:
# my lucky day is Monday  i love riding in blue cars

# %%
print("my lucky day is " + day, " i love riding in " + car )
# Out:
# my lucky day is wednesday  i love riding in random cars

# %%
def mypen():
    global pen
    pen = "reynolds"
    print('i use '+pen)

# %%
mypen()
# Out:
# i use reynolds

# %%
print('i use '+pen)
# Out:
# i use reynolds

# %%
pencil = "apsara"
def myuse():
    global pen
    pencil = "nataraj"
    pen = "reynolds"
    print('i use '+pen)
    print('i use '+ pencil)

# %%
print('i use '+ pencil)
# Out:
# i use apsara

# %%
myuse()
# Out:
# i use reynolds
# i use nataraj
