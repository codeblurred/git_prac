# %%
c = "cat"
c.capitalize()
# Out:
# 'Cat'

# %%
c1 = "cAt"
c.casefold()
# Out:
# 'cat'

# %%
c = "cat"
c.center(10)
# Out:
# '   cat    '

# %%
m = "madam"

m.count('m')
# Out:
# 2

# %%
my_str = "hey there"
print("the string is ", my_str)
print("the string is ", my_str.encode())
# Out:
# the string is  hey there
# the string is  b'hey there'

# %%
word = "Sum@n"
word.encode()
# Out:
# b'Sum@n'

# %%
Sentence = "hi  !! goodmorning , hope you are having a wonderful day."

Sentence.endswith(".")
# Out:
# True

# %%
s = "s\tu\tm\ta\tn"
s.expandtabs(3)
# Out:
# 's  u  m  a  n'

# %%
s = "thiS IS SUMAN"
s.isupper()
s.lower()
s1 = s.upper()
print(s1)
s.rsplit(", ")
# Out:
# THIS IS SUMAN
# ['thiS IS SUMAN']

# %%
s = "thiS IS SUMAN"
o = s.rsplit(" ")
print(o)
# Out:
# ['thiS', 'IS', 'SUMAN']

# %%
o = ('thiS IS SUMAN')
o.replace("thiS", "THIS")
# Out:
# 'THIS IS SUMAN'

# %%
s = "tHiS Is SuMan"
s.swapcase()
# Out:
# 'ThIs iS sUmAN'

# %%
o = 'this is suman and i love eating '
o.startswith("is")
# Out:
# False

# %%
print(10 < 12)

print(10 > 12)

print(10 == 12)
# Out:
# True
# False
# False

# %%
a = 132
b = 23
print(a, "is the value of a")
print(b,"is the value of b")

if a > b: 
    print("a is greater than b")
else: 
    print("b is greater than a")
# Out:
# 132 is the value of a
# 23 is the value of b
# a is greater than b

# %%
a = input("enter your value in integer format : ")
b = input("enter your value in integer format : ")


print(a, "is the value of a")
print(b,"is the value of b")

if a > b: 
    print("a is greater than b")
else: 
    print("b is greater than a")
# Out:
# enter your value in integer format : 200
# enter your value in integer format : 100
# 200 is the value of a
# 100 is the value of b
# a is greater than b

# %%
n = input("enter your name: ")
n1 = input("enter your age: ")

print("my name is ",n)
print('my age is', n1)
# Out:
# enter your name: vamshi
# enter your age: 29
# my name is  vamshi
# my age is 29
