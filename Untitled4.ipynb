# %%
print("Guido Van Rossum")
print(" hey there !!! welcome to the python session")
print("pagani")
print("audi")
# Out:
# Guido Van Rossum
#  hey there !!! welcome to the python session
# pagani
# audi

# %%
# constant and variable 
# 2 = 3 # not possible as it is constant  
a = 2
a

a = 3

# %%
a
# Out:
# 3

# %%
print(a)
print("a")
# Out:
# 3
# a

# %%
a = 1
b = "1"

c = 2j

print(type(a))
print(type(b))

print(type(c))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'complex'>

# %%
if 50 > 2:
    print("50 is greater than 2")
# Out:
# 50 is greater than 2

# %%
if 50 > 2:
    print("50 is greater than 2")
# Out:
# 50 is greater than 2

# %%
if -50 < 2:
    print("-50 is lesser than 2")
# Out:
# -50 is lesser than 2

# %%
a,b,c,d,e = "apple","banana","cake","doughnut","egg"
print(a,b,c,d,e)
# Out:
# apple banana cake doughnut egg
