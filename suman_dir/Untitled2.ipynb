# %%
a = 1
b= 10 
c= 20

order = "I have {} apple, {} bananas, {} eggs"
print(order.format(a,b,c))
# Out:
# I have 1 apple, 10 bananas, 20 eggs

# %%
print(" this is a double blackslash \\\\")
print(" this is /\\/\\/\\/\\/\\ mountain ")
print("python is\tawesome")
print("\\' \\ \\t \\")
print("\\\\ \\\\n \\\\t \\\\ \\'")
# Out:
#  this is a double blackslash \\
#  this is /\/\/\/\/\ mountain
# python is	awesome
# \' \ \t \
# \\ \\n \\t \\ \'

# %%
a= "today is a fresh day"
print(a.split(" "))
# Out:
# ['today', 'is', 'a', 'fresh', 'day']

# %%
d= " TRIUMPH DAYTONA "
print(d.lower())
print(d.replace(' ','#'))
# Out:
#  triumph daytona
# #TRIUMPH#DAYTONA#
