# %%
print("hi.. how are you?")
print("where are you??")
print("can you please call me?")
print("my fav car is merc")
# Out:
# hi.. how are you?
# where are you??
# can you please call me?
# my fav car is merc

# %%
a=2
a
a=3

# %%
a
# Out:
# 3

# %%
print(a)
# Out:
# 3
