# %%
print("hi.. how are you?")
print("where are you??")
print("can you please call me?")
print("my fav car is merc")
# Out:
# hi.. how are you?
# where are you??
# can you please call me?
# my fav car is merc

# %%
a=2
a
a=3

# %%
a
# Out:
# 3

# %%
print(a)
print("a")
# Out:
# 3
# a

# %%
a=1
b="1"
c=2j

print(type(a))
print(type(b))
print(type(c))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'complex'>

# %%
if 50 >2:
    print("50 is greater than 2")
# Out:
# 50 is greater than 2

# %%
if 50 <2:
    print("50 is lesser than 2")

# %%
if -50 <2:
    print("-50 is lesser than 2")
# Out:
# -50 is lesser than 2

# %%
a,b,c,d,e="apple","banana","cake","doughnut","egg"
print(a,b,c,d,e)
# Out:
# apple banana cake doughnut egg
